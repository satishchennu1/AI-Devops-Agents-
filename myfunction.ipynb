# %% [markdown]
# <a href="https://colab.research.google.com/github/satishchennu1/AI-Devops-Agents-/blob/main/myfunction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Functions in Python

def my_function():
  print("Hello from a function")

my_function()
# Out:
# Hello from a function

# %%
#  Return Values

def get_greeting():
    return "Hello from a function"

message = get_greeting()
print(message)
